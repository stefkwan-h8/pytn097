# %% [markdown]
# # Pandas
# package pandas digunakan untuk import, manipulasi, dan export data di Python

# %%
import numpy as np
import pandas as pd

# %%
# import data file csv ke Python pakai pandas

# path ke file bisa bersifat online, pakai link
df_gold = pd.read_csv("https://raw.githubusercontent.com/stefkwan-h8/dataset/main/gold.csv")

# path offline juga bisa
# pd.read_csv("gold.csv")

# %%
df_gold
# Out:
#             Date    Open     High     Low   Close  Volume Currency
# 0     2000-01-04   281.0   281.00   281.0   282.7       4      USD
# 1     2000-01-05   283.2   283.20   283.2   281.1      16      USD
# 2     2000-01-06   281.4   281.40   281.4   281.4       0      USD
# 3     2000-01-07   281.9   281.90   281.9   281.9       0      USD
# 4     2000-01-10   281.7   281.70   281.7   281.7       0      USD
# ...          ...     ...      ...     ...     ...     ...      ...
# 5701  2022-04-13  1970.5  1985.80  1966.3  1984.7  132029      USD
# 5702  2022-04-14  1981.6  1984.00  1962.7  1974.9  139424      USD
# 5703  2022-04-18  1978.5  2003.00  1974.4  1986.4  138130      USD
# 5704  2022-04-19  1981.2  1985.10  1945.5  1959.0  181440      USD
# 5705  2022-04-20  1952.1  1957.35  1941.2  1956.3       0      USD
#
# [5706 rows x 7 columns]

# %%
print(type(df_gold))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# melihat informasi data yang sudah di import
# .info(), .head(), .tail(), .describe()

df_gold.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5706 entries, 0 to 5705
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      5706 non-null   object
#  1   Open      5706 non-null   float64
#  2   High      5706 non-null   float64
#  3   Low       5706 non-null   float64
#  4   Close     5706 non-null   float64
#  5   Volume    5706 non-null   int64
#  6   Currency  5706 non-null   object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 312.2+ KB

# %%
# khusus untuk kolom data yang bersifat numerik, int atau float di dalam DataFrame, kita bisa minta angka2 agregasi statistiknya
df_gold.describe()
# Out:
#               Open         High          Low        Close         Volume
# count  5706.000000  5706.000000  5706.000000  5706.000000    5706.000000
# mean   1051.334064  1055.134048  1047.209294  1061.702755    1691.543113
# std     522.375070   524.396437   520.115979   528.987793   10821.666938
# min     255.000000   255.000000   255.000000   255.100000       0.000000
# 25%     462.850000   462.850000   462.150000   462.650000       5.000000
# 50%    1223.050000  1226.950000  1217.300000  1238.650000      56.000000
# 75%    1407.475000  1410.975000  1405.300000  1449.375000     243.000000
# max    2121.700000  2121.700000  2121.700000  2122.700000  214605.000000

# %%
# ubah kolom tanggal jadi tipe data tanggal
# set data kolom Date menjadi
df_gold["Date"] = pd.to_datetime(df_gold["Date"])

# %%
df_gold.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5706 entries, 0 to 5705
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      5706 non-null   datetime64[ns]
#  1   Open      5706 non-null   float64
#  2   High      5706 non-null   float64
#  3   Low       5706 non-null   float64
#  4   Close     5706 non-null   float64
#  5   Volume    5706 non-null   int64
#  6   Currency  5706 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 312.2+ KB

# %%
# baris baris pertama data
df_gold.head()
# Out:
#         Date   Open   High    Low  Close  Volume Currency
# 0 2000-01-04  281.0  281.0  281.0  282.7       4      USD
# 1 2000-01-05  283.2  283.2  283.2  281.1      16      USD
# 2 2000-01-06  281.4  281.4  281.4  281.4       0      USD
# 3 2000-01-07  281.9  281.9  281.9  281.9       0      USD
# 4 2000-01-10  281.7  281.7  281.7  281.7       0      USD

# %%
# n baris pertama data
df_gold.head(2)
# Out:
#         Date   Open   High    Low  Close  Volume Currency
# 0 2000-01-04  281.0  281.0  281.0  282.7       4      USD
# 1 2000-01-05  283.2  283.2  283.2  281.1      16      USD

# %%
# baris baris terakhir data
df_gold.tail(2)
# Out:
#            Date    Open     High     Low   Close  Volume Currency
# 5704 2022-04-19  1981.2  1985.10  1945.5  1959.0  181440      USD
# 5705 2022-04-20  1952.1  1957.35  1941.2  1956.3       0      USD

# %% [markdown]
# # Struktur data di Pandas
# 1. DataFrame
# 2. Series
#
# ## DataFrame
# tipe data 2 dimensi di Pandas
#
# bisa memproses tipe data numerik, datetime, object (non numerik), dll
#
# ### CRUD:
# READ ambil sebagian data di pandas DF:
# - ambil data per kolom
# - ambil data per baris
# - ambil data per baris dan kolom tertentu (slicing)
# - ambil 1 data di baris dan kolom tertentu (indexing)
#
# CREATE and edit UPDATE di pandas DF:
# - edit judul kolom
# - add/delete kolom
# - add/delete row
# - edit judul row (index)
#
# READ aggregate and filter di pandas DF:
# - agregasi data, seperti sum, mean, std dev, variance, max, min, dll
#   - per kolom
#   - per baris
#   - semua
# - grouping
#   - grup dulu datanya per kondisi tertentu, misalkan per 1 bulan, per tanggal tertentu, per value tertentu
#   - filter, dengan kondisi
#
# biasanya kita mau mengambil data dengan kondisi tertentu untuk di analisa. kita gunakan teknik tenik agregasi dan filter/grouping untuk melakukan tersebut.
#
# contohnya, di data harga stok emas di atas, kita bisa minta rata2 harga emas per bulan di tahun 2021.
# 1. filter dulu data khusus di tahun 2021
# 2. group datanya per bulan, untuk ini kita bisa add new column "bulan" untuk memudahkan
# 3. agregasi cari rata-rata untuk harga emas, per kolom "close" misalnya

# %%
pd.DataFrame([1,2,3,4,5])
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %% [markdown]
# ## Series
# tipe data 1 dimensi
#
# mirip list, atau array, satu set data
#
# tidak punya judul kolom
#
# punya kolom index

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s_gold = df_gold['Open'].head()
s_gold
# Out:
# 0    281.0
# 1    283.2
# 2    281.4
# 3    281.9
# 4    281.7
# Name: Open, dtype: float64

# %%
print(type(s_gold))
# Out:
# <class 'pandas.core.series.Series'>

# %%
s_gold2 = pd.Series([281.0,283.2,281.4,281.9,281.7])
s_gold2
# Out:
# 0    281.0
# 1    283.2
# 2    281.4
# 3    281.9
# 4    281.7
# dtype: float64

# %% [markdown]
# cara membuat Series bisa pakai function Series dari package pandas, pd.Series([]) diisi list data, isinya bisa non numerik, bisa tanggalan, bisa umerik.
#
# bisa juga kita mendapat Series dari data 1 dimensi yang kita extract dari DataFrame.
#
# *note: kalau extract data dari DataFrame tidak mau berubah jadi Series, kita bisa paksa dia jadi 2 dimensi contohnya:

# %%
df_gold[['Open']].head()
# Out:
#     Open
# 0  281.0
# 1  283.2
# 2  281.4
# 3  281.9
# 4  281.7

# %% [markdown]
# Sebuah pandas DataFrame memiliki kolom, dan baris.
#
# kolom datanya kisa bisa ambil per kolom sesuai judulnya dengan cara ['judul_kolom'] dari DataFrame
#
# kita bisa juga ambil data beberapa kolom sekaligus dengan memberi list judul2 kolom yang kita inginkan ['judul_kolom1', 'judul_kolom2', ...]
#
# code ambil kolom tertentu (1 atau banyak) dari DataFrame sebagai berikut:

# %%
df_gold["Date"] # 1 kolom, 1 string judul kolom, hasil akan jadi Series
# Out:
# 0      2000-01-04
# 1      2000-01-05
# 2      2000-01-06
# 3      2000-01-07
# 4      2000-01-10
#           ...
# 5701   2022-04-13
# 5702   2022-04-14
# 5703   2022-04-18
# 5704   2022-04-19
# 5705   2022-04-20
# Name: Date, Length: 5706, dtype: datetime64[ns]

# %%
df_gold[["Date","Open"]] # lebih dari 1 kolom, lebih dari 1 string, pakai list isi string, hasil akan jadi DataFrame
# Out:
#            Date    Open
# 0    2000-01-04   281.0
# 1    2000-01-05   283.2
# 2    2000-01-06   281.4
# 3    2000-01-07   281.9
# 4    2000-01-10   281.7
# ...         ...     ...
# 5701 2022-04-13  1970.5
# 5702 2022-04-14  1981.6
# 5703 2022-04-18  1978.5
# 5704 2022-04-19  1981.2
# 5705 2022-04-20  1952.1
#
# [5706 rows x 2 columns]

# %% [markdown]
# tipe data Series bisa kita gabungkan menjadi sebuah DataFrame

# %%
s_nama_murid = pd.Series(["Andi", "Budi", "Cindy"])
s_nilai_ujian = pd.Series([80, 75, 78])

print(s_nama_murid)
print(s_nilai_ujian)
# Out:
# 0     Andi
# 1     Budi
# 2    Cindy
# dtype: object
# 0    80
# 1    75
# 2    78
# dtype: int64

# %%
df_kelas = pd.DataFrame({
    "Nama Murid":s_nama_murid,
    "Nilai Ujian":s_nilai_ujian
    })

df_kelas
# Out:
#   Nama Murid  Nilai Ujian
# 0       Andi           80
# 1       Budi           75
# 2      Cindy           78

# %% [markdown]
# sebenarnya tipe data di atas, tidak harus berbentuk DataFrame. Karena cuma ada 2 kolom, dan kolom "Nama Murid" ceritanya akan bersifat unik, kita bisa simpan "Nama Murid" sebagai index saja.
#
# Kita bisa keep datanya dalam bentuk 1 dimensi, Series.
#
# Kita bisa set kolom "Nama Murid" sebagai index.

# %%
s_kelas = pd.Series([80, 75, 78], index=["Andi", "Budi", "Cindy"])
s_kelas
# Out:
# Andi     80
# Budi     75
# Cindy    78
# dtype: int64

# %% [markdown]
# judul index (judul baris) yang lebih deskriptif daripada angka urut, bisa membantu kita saat mau ambil data baris tertentu. Tidak hanya baris ke 5-10, kita bisa minta baris "Andi" misalnya.
#
# untuk mengambil data per baris kita pakai `.loc[]`

# %%
s_kelas.loc["Andi"] # akan menjadi 1 value saja
# Out:
# 80

# %%
s_kelas.loc[["Andi", "Budi"]] # akan menjadi Series lagi
# Out:
# Andi    80
# Budi    75
# dtype: int64

# %% [markdown]
# di DataFrame kita bisa melakukan hal yang sama, juga menggunakan `.loc[]`
#
# *note: tanpa `.loc` maka `[]` kita mengambil per kolom. dengan `.loc` maka `[]` mengambil per baris dengan melihat judul baris (index)

# %%
# ambil data per baris di dataframe
df_kelas
# Out:
#   Nama Murid  Nilai Ujian
# 0       Andi           80
# 1       Budi           75
# 2      Cindy           78

# %%
df_kelas.loc[0]
# Out:
# Nama Murid     Andi
# Nilai Ujian      80
# Name: 0, dtype: object

# %% [markdown]
# hasilnya adalah sebuah Series, judul kolom kita menjadi index Series tersebut.

# %%
df_kelas.loc[[0, 1]]
# Out:
#   Nama Murid  Nilai Ujian
# 0       Andi           80
# 1       Budi           75

# %% [markdown]
# kalau kita ambil beberapa baris, hasilnya adalah sebuah DataFrame

# %%
# Series vs DataFrame

# %% [markdown]
# Ada 2 tipe data custom yang dibuat oleh package Pandas
# - Series
# - DataFrame
#
# fungsi2 built-in yang ada di package Pandas bisa digunakan keduanya. cara ambil data per baris tertentu. agregasi pakai mean, max, min, describe, ...
#
# tapi ada fungsi2 built-in buatan package Pandas yang khusus untuk tipe data tertentu. khusus Series, atau khusus DataFrame
#
# ada juga sifat2 dari kedua tipe data tersebut yang berbeda:
# - Series tidak punya judul kolom, DataFrame punya
# - Series bersifat 1 dimensi mirip Dictionary, DataFrame bersifat 2 dimensi
#
# Pandas otomatis convert data yang 1D menjadi Series. 2D menjadi DataFrame.
#
# Numpy adalah package Python berbeda, yang dibuat khusus untuk handling data tipe numerik. Di package Numpy ada tipe data custom namanya
# - Numpy Array
#
# Numpy Array ini mirip list tapi bisa handle data tipe numerik saja.
#
# Package adalah kumpulan code Python yang sudah disimpan ke sebuah file `.py`
#
# code code Python tidak harus kita buat semua dari awal. Ada banyak orang lain yang sudah buatkan. Bahkan ada komunitas orang orang yang membuat code Python. Bisa dilihat di https://pypi.org/
#
# code Python yang sudah dibuat, dikumpulkan ke 1 file `.py` jadilah sebuah "module"
#
# banyak file `.py` dikumpulkan ke sebuah folder, kita panggil sebagai "package"
#
# kenapa kita pakai code buatan orang lain?
#
# karena banyak fungsionalitas tambahan yang tidak ada di base Python
#
# ---
#
# tidak ada limitasi file size di Python, Numpy dan Pandas bisa handle data sebesar kekuatan komputer kita (memory atau processing power)
#
# ---
#
# pros menggunakan Python untuk data handling, nanti bisa kita sambungkan ke API, bisa juga jadi aplikasi, bisa juga kita add fitur forecasting pakai Machine Learning, dan lain2
#
# kalau fokus kita hanya data handling yang jumlah data cukup kecil muat di Excel, sebenarnya pakai Excel saja juga bisa dan lebih mudah karena ada GUI (klik klik, icon, drag n drop, tidak text based programming)
#
# kalau data lebih besar dan tidak mau programming, banyak juga orang yang memilik pakai Power BI

# %%
# selain bisa import data, dan baca data per baris/kolom
# kita bisa ambil data dengan kondisi tertentu

df_gold.head()
# Out:
#         Date   Open   High    Low  Close  Volume Currency
# 0 2000-01-04  281.0  281.0  281.0  282.7       4      USD
# 1 2000-01-05  283.2  283.2  283.2  281.1      16      USD
# 2 2000-01-06  281.4  281.4  281.4  281.4       0      USD
# 3 2000-01-07  281.9  281.9  281.9  281.9       0      USD
# 4 2000-01-10  281.7  281.7  281.7  281.7       0      USD

# %%
df_gold.shape
# Out:
# (5706, 7)

# %%
# misalkan kita mau ambil data khusus yang volume diatas 100

# kondisi adalah data yang ada di kolom Volume, nilainya lebih dari 100
kondisi = df_gold["Volume"] > 100
# ini menjadi kumpulan boolean

# kumpulan boolean kondisi itu kita gunakan sebagai index, sebagai filter
df_gold[kondisi]

# teknik ini juga disebut sebagai "query"
# Out:
#            Date    Open    High     Low   Close  Volume Currency
# 17   2000-01-28   287.1   287.8   280.5   283.0   14493      USD
# 18   2000-01-31   283.0   284.5   282.1   283.2    2445      USD
# 19   2000-02-01   282.3   284.0   282.2   282.5     502      USD
# 20   2000-02-02   283.5   286.7   283.5   284.9     227      USD
# 21   2000-02-03   284.3   288.5   284.3   287.2     177      USD
# ...         ...     ...     ...     ...     ...     ...      ...
# 5700 2022-04-12  1957.4  1982.7  1953.0  1976.1  172386      USD
# 5701 2022-04-13  1970.5  1985.8  1966.3  1984.7  132029      USD
# 5702 2022-04-14  1981.6  1984.0  1962.7  1974.9  139424      USD
# 5703 2022-04-18  1978.5  2003.0  1974.4  1986.4  138130      USD
# 5704 2022-04-19  1981.2  1985.1  1945.5  1959.0  181440      USD
#
# [2300 rows x 7 columns]

# %%
# ditulis langsung juga bisa

df_gold[df_gold["Volume"] > 100]
# Out:
#            Date    Open    High     Low   Close  Volume Currency
# 17   2000-01-28   287.1   287.8   280.5   283.0   14493      USD
# 18   2000-01-31   283.0   284.5   282.1   283.2    2445      USD
# 19   2000-02-01   282.3   284.0   282.2   282.5     502      USD
# 20   2000-02-02   283.5   286.7   283.5   284.9     227      USD
# 21   2000-02-03   284.3   288.5   284.3   287.2     177      USD
# ...         ...     ...     ...     ...     ...     ...      ...
# 5700 2022-04-12  1957.4  1982.7  1953.0  1976.1  172386      USD
# 5701 2022-04-13  1970.5  1985.8  1966.3  1984.7  132029      USD
# 5702 2022-04-14  1981.6  1984.0  1962.7  1974.9  139424      USD
# 5703 2022-04-18  1978.5  2003.0  1974.4  1986.4  138130      USD
# 5704 2022-04-19  1981.2  1985.1  1945.5  1959.0  181440      USD
#
# [2300 rows x 7 columns]

# %%
# kita juga bisa mengambil data dengan lebih dari 1 kondisi
# misalkan kita mau data harga stok emas di tahun 2000 dan di bulan 3 saja

# untuk memudahkan pembuatan kondisi, kita tambahkan 2 kolom baru: Tahun dan Bulan
df_gold["Date"]
# Out:
# 0      2000-01-04
# 1      2000-01-05
# 2      2000-01-06
# 3      2000-01-07
# 4      2000-01-10
#           ...
# 5701   2022-04-13
# 5702   2022-04-14
# 5703   2022-04-18
# 5704   2022-04-19
# 5705   2022-04-20
# Name: Date, Length: 5706, dtype: datetime64[ns]

# %%
df_gold["Date"].dt.year # kita masukin ke kolom baru dengan judul "Tahun"
# Out:
# 0       2000
# 1       2000
# 2       2000
# 3       2000
# 4       2000
#         ...
# 5701    2022
# 5702    2022
# 5703    2022
# 5704    2022
# 5705    2022
# Name: Date, Length: 5706, dtype: int64

# %%
df_gold["Date"].dt.month
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 5701    4
# 5702    4
# 5703    4
# 5704    4
# 5705    4
# Name: Date, Length: 5706, dtype: int64

# %%
# nambah kolom baru, kasih judul, kasih datanya
df_gold["Tahun"] = df_gold["Date"].dt.year
df_gold["Bulan"] = df_gold["Date"].dt.month

df_gold.head()
# Out:
#         Date   Open   High    Low  Close  Volume Currency  Tahun  Bulan
# 0 2000-01-04  281.0  281.0  281.0  282.7       4      USD   2000      1
# 1 2000-01-05  283.2  283.2  283.2  281.1      16      USD   2000      1
# 2 2000-01-06  281.4  281.4  281.4  281.4       0      USD   2000      1
# 3 2000-01-07  281.9  281.9  281.9  281.9       0      USD   2000      1
# 4 2000-01-10  281.7  281.7  281.7  281.7       0      USD   2000      1

# %%
# kita buat 2 kondisi: Tahun 2000, Bulan 3

kondisi1 = df_gold["Tahun"] == 2000
kondisi2 = df_gold["Bulan"] == 3

# dua kondisi, kita mau dua2nya harus True, kita pakai "&" and

kondisi = kondisi1 & kondisi2

df_gold[kondisi]
# Out:
#          Date   Open   High    Low  Close  Volume Currency  Tahun  Bulan
# 39 2000-03-01  291.5  291.5  291.5  291.5       0      USD   2000      3
# 40 2000-03-02  288.2  288.2  288.2  288.2     100      USD   2000      3
# 41 2000-03-03  288.8  288.8  288.8  288.8      10      USD   2000      3
# 42 2000-03-06  287.9  287.9  287.9  287.9       0      USD   2000      3
# 43 2000-03-07  292.2  292.2  292.2  292.2       0      USD   2000      3
# 44 2000-03-08  288.9  288.9  288.9  288.9     100      USD   2000      3
# 45 2000-03-09  291.2  291.2  291.2  291.2       0      USD   2000      3
# 46 2000-03-10  288.6  288.6  288.6  288.6       4      USD   2000      3
# 47 2000-03-13  290.1  290.1  290.1  290.1       0      USD   2000      3
# 48 2000-03-14  288.3  288.3  288.3  288.3       0      USD   2000      3
# 49 2000-03-15  288.7  288.7  288.7  288.7       0      USD   2000      3
# 50 2000-03-16  286.1  286.1  286.1  286.1       1      USD   2000      3
# ...

# %%
# langsung juga boleh
df_gold[(df_gold['Tahun'] == 2000) & (df_gold["Bulan"] == 3)]
# Out:
#          Date   Open   High    Low  Close  Volume Currency  Tahun  Bulan
# 39 2000-03-01  291.5  291.5  291.5  291.5       0      USD   2000      3
# 40 2000-03-02  288.2  288.2  288.2  288.2     100      USD   2000      3
# 41 2000-03-03  288.8  288.8  288.8  288.8      10      USD   2000      3
# 42 2000-03-06  287.9  287.9  287.9  287.9       0      USD   2000      3
# 43 2000-03-07  292.2  292.2  292.2  292.2       0      USD   2000      3
# 44 2000-03-08  288.9  288.9  288.9  288.9     100      USD   2000      3
# 45 2000-03-09  291.2  291.2  291.2  291.2       0      USD   2000      3
# 46 2000-03-10  288.6  288.6  288.6  288.6       4      USD   2000      3
# 47 2000-03-13  290.1  290.1  290.1  290.1       0      USD   2000      3
# 48 2000-03-14  288.3  288.3  288.3  288.3       0      USD   2000      3
# 49 2000-03-15  288.7  288.7  288.7  288.7       0      USD   2000      3
# 50 2000-03-16  286.1  286.1  286.1  286.1       1      USD   2000      3
# ...

# %% [markdown]
# kalau kondisi salah satu saja yang benar juga OK, kita bisa pakai or `|`

# %%
# misalkan khusus yang Volume 100 atau 1000
df_gold[(df_gold['Volume'] == 100) | (df_gold["Volume"] == 1000)]
# Out:
#            Date    Open    High     Low   Close  Volume Currency  Tahun  Bulan
# 40   2000-03-02   288.2   288.2   288.2   288.2     100      USD   2000      3
# 44   2000-03-08   288.9   288.9   288.9   288.9     100      USD   2000      3
# 86   2000-05-08   276.4   276.4   276.4   276.4     100      USD   2000      5
# 104  2000-06-02   275.0   283.0   273.0   281.4    1000      USD   2000      6
# 218  2000-11-14   264.9   264.9   264.9   264.9     100      USD   2000     11
# 878  2003-07-16   343.1   343.1   343.1   343.1     100      USD   2003      7
# 1294 2005-03-21   431.1   431.1   431.1   431.1     100      USD   2005      3
# 1457 2005-11-09   466.3   466.3   466.3   466.3     100      USD   2005     11
# 1748 2007-01-08   607.5   607.5   607.5   607.5    1000      USD   2007      1
# 2455 2009-10-27  1039.5  1042.1  1035.5  1034.7     100      USD   2009     10
# 2619 2010-06-23  1240.2  1245.1  1226.9  1234.1     100      USD   2010      6
# ...

# %% [markdown]
# sekian untuk filtering
#
# # Grouping & Aggregation
#
# seringkali kita perlu grup dan agregat data sekaligus. Jarang kita perlu agregat saja.
#
# contohnya, kita bisa cari rata2 harga stok emas dari data kita diatas. (agregat)
#
# tapi seringali kita perlu cari rata2 harga stok emas per tahun. (group + agregat)
#
# dengan grouping dan aggregation yang kita pakai bareng, kita bisa melihat trend, contohnya trend harga stok emas dari tahun ke tahun

# %%
# lihat rata2 harga stok emas dari kolom Close untuk per tahun

df_gold.head()
# Out:
#         Date   Open   High    Low  Close  Volume Currency  Tahun  Bulan
# 0 2000-01-04  281.0  281.0  281.0  282.7       4      USD   2000      1
# 1 2000-01-05  283.2  283.2  283.2  281.1      16      USD   2000      1
# 2 2000-01-06  281.4  281.4  281.4  281.4       0      USD   2000      1
# 3 2000-01-07  281.9  281.9  281.9  281.9       0      USD   2000      1
# 4 2000-01-10  281.7  281.7  281.7  281.7       0      USD   2000      1

# %%
# agregasi, kolom Close, cari mean
df_gold["Close"].mean()
# Out:
# 1061.7027549947425

# %%
# grouping per tahun, kolom Tahun
df_gold.groupby(["Tahun"])["Close"].mean()
# Out:
# Tahun
# 2000     278.885141
# 2001     271.068826
# 2002     310.479032
# 2003     363.620884
# 2004     409.579839
# 2005     445.112749
# 2006     603.977381
# 2007     697.005159
# 2008     870.982609
# 2009     974.149206
# 2010    1227.501984
# 2011    1572.135714
# 2012    1669.157143
# 2013    1407.275781
# 2014    1333.914504
# 2015    1243.416667
# 2016    1320.624528
# 2017    1370.485303
# 2018    1409.398674
# 2019    1468.902642
# 2020    1813.986604
# 2021    1809.597170
# 2022    1894.151266
# Name: Close, dtype: float64

# %%
# visualisasi
df_gold_mean_per_tahun = df_gold.groupby(["Tahun"])["Close"].mean()

df_gold_mean_per_tahun.plot()
# Out:
# <Axes: xlabel='Tahun'>

# %%
df_gold_mean_per_tahun.plot(kind="bar")
# Out:
# <Axes: xlabel='Tahun'>

# %% [markdown]
# beberapa hal yang mau dibahas:
# - missing value, handling
# - invalid value, checking
# - ubah judul kolom
# - delete kolom
# - concat, untuk combine data, merge

# %%
# untuk contoh data yang ada missing value, kita import data game NBA dari file https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv

df_nba = pd.read_csv("https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv")
df_nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
df_nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %% [markdown]
# # handling missing values
# 1. drop semua baris data yang ada missing value
# 2. drop kolom yang punya banyak missing value
# 3. isi missing value dengan suatu value tertentu, untuk contoh kali ini, yang tidak ada notes, kita tulis saja "no notes"

# %%
# drop semua baris data yang ada missing value

df_nba_1 = df_nba.dropna()
df_nba_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5424 entries, 930 to 124863
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gameorder      5424 non-null   int64
#  1   game_id        5424 non-null   object
#  2   lg_id          5424 non-null   object
#  3   _iscopy        5424 non-null   int64
#  4   year_id        5424 non-null   int64
#  5   date_game      5424 non-null   object
#  6   seasongame     5424 non-null   int64
#  7   is_playoffs    5424 non-null   int64
#  8   team_id        5424 non-null   object
#  9   fran_id        5424 non-null   object
#  10  pts            5424 non-null   int64
#  11  elo_i          5424 non-null   float64
#  12  elo_n          5424 non-null   float64
#  13  win_equiv      5424 non-null   float64
#  14  opp_id         5424 non-null   object
#  15  opp_fran       5424 non-null   object
#  16  opp_pts        5424 non-null   int64
# ...

# %%
# drop kolom data yang ada missing value
df_nba_2 = df_nba.dropna(axis=1)
df_nba_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 22 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
# isi missing value
# biasanya isi per kolom
df_nba_3 = df_nba.copy()

df_nba_3["notes"] = df_nba_3["notes"].fillna("no notes")
df_nba_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df_nba_3.head(10)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7          4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8          5  194611020STB   NBA        1     1947  11/2/1946           1
# 9          5  194611020STB   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id       fran_id  ...  win_equiv  opp_id      opp_fran  \
# 0            0     TRH       Huskies  ...  40.294830     NYK        Knicks
# ...

# %% [markdown]
# # invalid value
# ada data yang tidak masuk akal di dataset kita.
#
# case by case, misalkan untuk data game basket nasional Amerika NBA, aneh kalau ada game yang skor nya 0, atau skor dibawah 10.
#
# bisa juga kita cari tren datanya terlebih dahulu pakai describe, atau teknik agregasi lainnya, sebelum lanjut cek invalid values
#
# bisa juga tipe data tercampur, seperti tulisan "forfeit" di kolom pts yang harusnya isi angka semua.

# %%
df_nba.describe()
# Out:
#            gameorder        _iscopy        year_id     seasongame  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean    31579.000000       0.500000    1988.200374      43.533733
# std     18231.927643       0.500002      17.582309      25.375178
# min         1.000000       0.000000    1947.000000       1.000000
# 25%     15790.000000       0.000000    1975.000000      22.000000
# 50%     31579.000000       0.500000    1990.000000      43.000000
# 75%     47368.000000       1.000000    2003.000000      65.000000
# max     63157.000000       1.000000    2015.000000     108.000000
#
#          is_playoffs            pts          elo_i          elo_n  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean        0.063857     102.729982    1495.236055    1495.236055
# std         0.244499      14.814845     112.139945     112.461687
# min         0.000000       0.000000    1091.644500    1085.774400
# ...

# %%
# di kasus ini, kita perhatikan keanehan pts dengan value 0
# kita gunakan teknik filter/ query, untuk cari data mana yang kolom pts punya value 0
kondisi = df_nba["pts"] == 0

df_nba[kondisi]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 26684      13343  197210260VIR   ABA        1     1973  10/26/1972
#
#        seasongame  is_playoffs team_id  fran_id  ...  win_equiv  opp_id  \
# 26684           7            0     DNR  Nuggets  ...  40.408863     VIR
#
#        opp_fran  opp_pts  opp_elo_i opp_elo_n  game_location  game_result  \
# 26684   Squires        2  1484.1907  1487.083              A            L
#
#        forecast                           notes
# 26684  0.328948  at Richmond VA; forfeit to VIR
#
# [1 rows x 23 columns]

# %%
kondisi = df_nba["pts"] == 2

df_nba[kondisi]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 26685      13343  197210260VIR   ABA        0     1973  10/26/1972
#
#        seasongame  is_playoffs team_id  fran_id  ...  win_equiv  opp_id  \
# 26685           8            0     VIR  Squires  ...  43.514412     DNR
#
#        opp_fran  opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  \
# 26685   Nuggets        0  1460.3387  1457.4464              H            W
#
#        forecast                           notes
# 26685  0.671052  at Richmond VA; forfeit to VIR
#
# [1 rows x 23 columns]

# %% [markdown]
# opsi handling invalid values:
# - kita bisa hapus
# - kita bisa edit jadi value yang normal
# - kita bisa note secara terpisah dan dibiarkan

# %%
# hapus
# hapus 1 baris menggunakan index
df_nba_4 = df_nba.drop(index=[26684])

kondisi = df_nba_4["pts"] == 0
df_nba_4[kondisi]
# Out:
# Empty DataFrame
# Columns: [gameorder, game_id, lg_id, _iscopy, year_id, date_game, seasongame, is_playoffs, team_id, fran_id, pts, elo_i, elo_n, win_equiv, opp_id, opp_fran, opp_pts, opp_elo_i, opp_elo_n, game_location, game_result, forecast, notes]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# kita bisa kasih note seperti ini, kalau ada 1 game yang forfeit yang pts nya 0 dan 2, tapi kita biarkan di dalam dataset.

# %%
# edit jadi value normal
df_nba_5 = df_nba.copy()

df_nba_5.loc[26684, "pts"] = 100

df_nba_5.describe()
# Out:
#            gameorder        _iscopy        year_id     seasongame  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean    31579.000000       0.500000    1988.200374      43.533733
# std     18231.927643       0.500002      17.582309      25.375178
# min         1.000000       0.000000    1947.000000       1.000000
# 25%     15790.000000       0.000000    1975.000000      22.000000
# 50%     31579.000000       0.500000    1990.000000      43.000000
# 75%     47368.000000       1.000000    2003.000000      65.000000
# max     63157.000000       1.000000    2015.000000     108.000000
#
#          is_playoffs            pts          elo_i          elo_n  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean        0.063857     102.730774    1495.236055    1495.236055
# std         0.244499      14.812027     112.139945     112.461687
# min         0.000000       2.000000    1091.644500    1085.774400
# ...

# %% [markdown]
# minta list columns

# %%
df_nba.columns
# Out:
# Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#        'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#        'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#        'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#       dtype='object')

# %%
# hapus kolom juga bisa pakai drop
df_nba.drop(columns=['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id',
       'seasongame', 'is_playoffs', 'fran_id', 'elo_i',
       'elo_n', 'win_equiv', 'opp_fran', 'opp_elo_i',
       'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'])
# Out:
#         date_game team_id  pts opp_id  opp_pts
# 0       11/1/1946     TRH   66    NYK       68
# 1       11/1/1946     NYK   68    TRH       66
# 2       11/2/1946     CHS   63    NYK       47
# 3       11/2/1946     NYK   47    CHS       63
# 4       11/2/1946     DTF   33    WSC       50
# ...           ...     ...  ...    ...      ...
# 126309  6/11/2015     CLE   82    GSW      103
# 126310  6/14/2015     GSW  104    CLE       91
# 126311  6/14/2015     CLE   91    GSW      104
# 126312  6/16/2015     CLE   97    GSW      105
# 126313  6/16/2015     GSW  105    CLE       97
#
# [126314 rows x 5 columns]

# %%
# bisa juga kita pilih kolom2 yang mau di keep, slicing
df_nba[['date_game',	'team_id',	'pts',	'opp_id',	'opp_pts']]
# Out:
#         date_game team_id  pts opp_id  opp_pts
# 0       11/1/1946     TRH   66    NYK       68
# 1       11/1/1946     NYK   68    TRH       66
# 2       11/2/1946     CHS   63    NYK       47
# 3       11/2/1946     NYK   47    CHS       63
# 4       11/2/1946     DTF   33    WSC       50
# ...           ...     ...  ...    ...      ...
# 126309  6/11/2015     CLE   82    GSW      103
# 126310  6/14/2015     GSW  104    CLE       91
# 126311  6/14/2015     CLE   91    GSW      104
# 126312  6/16/2015     CLE   97    GSW      105
# 126313  6/16/2015     GSW  105    CLE       97
#
# [126314 rows x 5 columns]

# %%
# ubah judul kolom

df_nba.head(1)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...   40.29483     NYK    Knicks       68
#
#   opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# 0    1300.0  1306.7233              H            L  0.640065   NaN
#
# [1 rows x 23 columns]

# %%
df_nba_6 = df_nba.rename(columns = {
    "game_id": "game_unique_id",
    "fran_id": "team_brand"
})

df_nba_6
# Out:
#         gameorder game_unique_id lg_id  _iscopy  year_id  date_game  \
# 0               1   194611010TRH   NBA        0     1947  11/1/1946
# 1               1   194611010TRH   NBA        1     1947  11/1/1946
# 2               2   194611020CHS   NBA        0     1947  11/2/1946
# 3               2   194611020CHS   NBA        1     1947  11/2/1946
# 4               3   194611020DTF   NBA        0     1947  11/2/1946
# ...           ...            ...   ...      ...      ...        ...
# 126309      63155   201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156   201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156   201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157   201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157   201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id team_brand  ...  win_equiv  opp_id  \
# ...
